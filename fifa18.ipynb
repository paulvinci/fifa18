# %% [markdown]
# ## Datacamp Fifa 18

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/pbrenotv/Desktop/CompleteDataset.csv', dtype='object', index_col=0)
df.head()
# Out:
#                 Name Age                                            Photo  \
# 0  Cristiano Ronaldo  32   https://cdn.sofifa.org/48/18/players/20801.png
# 1           L. Messi  30  https://cdn.sofifa.org/48/18/players/158023.png
# 2             Neymar  25  https://cdn.sofifa.org/48/18/players/190871.png
# 3          L. Suárez  30  https://cdn.sofifa.org/48/18/players/176580.png
# 4           M. Neuer  31  https://cdn.sofifa.org/48/18/players/167495.png
#
#   Nationality                                 Flag Overall Potential  \
# 0    Portugal  https://cdn.sofifa.org/flags/38.png      94        94
# 1   Argentina  https://cdn.sofifa.org/flags/52.png      93        93
# 2      Brazil  https://cdn.sofifa.org/flags/54.png      92        94
# 3     Uruguay  https://cdn.sofifa.org/flags/60.png      92        92
# 4     Germany  https://cdn.sofifa.org/flags/21.png      92        92
#
#                   Club                                   Club Logo   Value  \
# ...

# %%
df['Club'].value_counts().index[:10]
# Out:
# Index(['Villarreal CF', 'Olympique Lyonnais', 'VfL Wolfsburg', 'FC Nantes',
#        'Borussia Dortmund', 'OGC Nice', 'Manchester United', 'UD Las Palmas',
#        'Newcastle United', 'Chelsea'],
#       dtype='object')

# %%
df['Overall'] = df['Overall'].map(int)

# %%
df['Potential'] = df['Potential'].map(int)

# %%
df.Club.fillna('Villarreal CF', inplace=True)

# %%
sns.lmplot( x="Overall", y="Potential", data=df, fit_reg=False, hue='Club', legend=True)

# %%
df['Club'].value_counts()[:2].plot(kind='bar', figsize=(10, 5), grid=False, color=['r', 'g'])

# %%
df['Overall'].value_counts().plot(kind='hist')

# %%
best_players=df['Overall']>80 
df_best=df[best_players]
sns.lmplot( x="Overall", y="Potential", data=df_best, fit_reg=False, hue='Nationality', legend=False)

# %%
df_best['Nationality'].value_counts()[:10]
# Out:
# Spain        65
# France       39
# Germany      36
# Brazil       33
# Italy        27
# England      21
# Argentina    21
# Portugal     18
# Belgium      16
# Croatia      12
# Name: Nationality, dtype: int64

# %%
df_best['Nationality'].value_counts()[:10].plot(kind='bar')

# %%
df_best
# Out:
#                   Name Age                                            Photo  \
# 0    Cristiano Ronaldo  32   https://cdn.sofifa.org/48/18/players/20801.png
# 1             L. Messi  30  https://cdn.sofifa.org/48/18/players/158023.png
# 2               Neymar  25  https://cdn.sofifa.org/48/18/players/190871.png
# 3            L. Suárez  30  https://cdn.sofifa.org/48/18/players/176580.png
# 4             M. Neuer  31  https://cdn.sofifa.org/48/18/players/167495.png
# 5       R. Lewandowski  28  https://cdn.sofifa.org/48/18/players/188545.png
# 6               De Gea  26  https://cdn.sofifa.org/48/18/players/193080.png
# 7            E. Hazard  26  https://cdn.sofifa.org/48/18/players/183277.png
# 8             T. Kroos  27  https://cdn.sofifa.org/48/18/players/182521.png
# 9           G. Higuaín  29  https://cdn.sofifa.org/48/18/players/167664.png
# 10        Sergio Ramos  31  https://cdn.sofifa.org/48/18/players/155862.png
# ...

# %%
df['Value']=df['Value'].replace('€','')
sns.lmplot(data=df_best, x='Overall', y='Value', hue='Age', fit_reg=False)

# %%
df_best['match']=df_best['Potential']==df_best['Overall']
# Out:
# C:\Users\pbrenotv\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_best['match'][:10]
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9     True
# Name: match, dtype: bool

# %%
sns.lmplot(data=df_best, x='Overall', y='Age', hue='match', fit_reg=False, legend=True)
#plt.title('MATCH FIFA 2018')

# %%
df['Nationality'].value_counts()>20
# Out:
# England                 True
# Germany                 True
# Spain                   True
# France                  True
# Argentina               True
# Brazil                  True
# Italy                   True
# Colombia                True
# Japan                   True
# Netherlands             True
# Republic of Ireland     True
# United States           True
# Chile                   True
# Sweden                  True
# Portugal                True
# Mexico                  True
# Denmark                 True
# Poland                  True
# Norway                  True
# Korea Republic          True
# Saudi Arabia            True
# Russia                  True
# Scotland                True
# Turkey                  True
# Belgium                 True
# Austria                 True
# Switzerland             True
# Australia               True
# Uruguay                 True
# Serbia                  True
#                        ...
# Thailand               False
# ...

# %%
best_players_lean=np.logical_and(df['Overall']>80, df['Nationality'].value_counts()>10)
df_bestlean=df[best_players_lean]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-181-583e61c56fb4> in <module>()
# ----> 1 best_players_lean=np.logical_and(df['Overall']>80, df['Nationality'].value_counts()>10)
#       2 df_bestlean=df[best_players_lean]
#
# ValueError: operands could not be broadcast together with shapes (17981,) (165,)
